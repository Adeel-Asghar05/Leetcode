# %% [markdown]
# <a href="https://colab.research.google.com/github/Adeel-Asghar05/Leetcode/blob/main/LeetCode.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("my name is adeel asghar")
# Out:
# my name is adeel asghar

# %%
print("i am from chishtaina dn study in islamia university of bahawalpur")
# Out:
# i am from chishtaina dn study in islamia university of bahawalpur

# %%
a=5

# %%
b=7

# %%
print(a+b)
# Out:
# 12

# %%
print ("india","Pakistan","Nepal")
# Out:
# india Pakistan Nepal

# %%
print ("india","Pakistan","4", sep="+")
# Out:
# india+Pakistan+4

# %%
print ("2","3","4","=","23", sep="+")
# Out:
# 2+3+4+=+23

# %%
print ({"name": "adeel", "age": 22, "gender":"male"})
# Out:
# {'name': 'adeel', 'age': 22, 'gender': 'male'}

# %%
name = "Adeel"
print(name)
# Out:
# Adeel

# %%
# Python is dynamic type lenguage means no need to declear datatype, pyhton is enough meture to understand datatype autmoatically,

# %%
#python is dynamic binding which means in python veriable can change datatype any time

# %%
#input in pyhton
first_num = input("Marks of subject 1 = ")
second_num = input("Marks of subject 2 = ")
third_num = input("Marks of subject 3 = ")
type(third_num)
# Out:
# Marks of subject 1 = 45
# Marks of subject 2 = 56
# Marks of subject 3 = 89
# str

# %%
first_num = int(first_num)
second_num= int(second_num)
third_num = int (third_num)
sum_of_numbers= first_num + second_num + third_num
print("total numbers = ", sum_of_numbers)
Average = sum_of_numbers/3
print("Average is", Average)
# Out:
# total numbers =  190
# Average is 63.333333333333336

# %%
type(third_num)
# Out:
# int

# %%
#reverse string
def reverse_string(s):
  return s[::-1]
  # print(reverse_string("adeel"))

# %%
print(reverse_string("hello"))
# Out:
# olleh

# %%
#dictionary is key value storage are very important
dic={"name": "Adeel Asghar", "Age": 22, "Gender": "Male"}
print(dic)
# Out:
# {'name': 'Adeel Asghar', 'Age': 22, 'Gender': 'Male'}

# %%
x=4
squre= lambda x: x*x

# %%
print(squre)
# Out:
# <function <lambda> at 0x7f6335686340>
